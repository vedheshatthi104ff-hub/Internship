# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/vedheshatthi104ff-hub/Internship/blob/main/work/notebooks/w01_research_question.ipynb?flush_cache=true)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*
#
# Going with Refresh / Content Opportunity Scoring. This one feels the most useful in practice — instead of just describing patterns, it actually produces something a content team could use tomorrow: a ranked list of pages to look at first. There's also already a starter pipeline built for exactly this, so I can run it, see real precision numbers, and use that to justify why this lane is worth the next 7 weeks.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

import os

# only clone if it's not already there
if not os.path.exists("/content/Internship"):
    # !git clone https://github.com/vedheshatthi104ff-hub/Internship.git /content/Internship

# always jump to the correct root, regardless of where we currently are
# %cd /content/Internship

# !ls data/raw/
# %cd /content/Internship
# !ls data/raw/
# Out:
# /content/Internship
# content_refresh_anonymized.csv
# /content/Internship
# content_refresh_anonymized.csv

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*
#
# ## Research Question
#
# Which pages should be reviewed first for refresh based on their search performance and engagement metrics?
#
# ### Decision
#
# Identify and rank pages that should be prioritized for content review.
#
# ### Action
#
# The content team can:
# - Update outdated content
# - Improve titles and meta descriptions
# - Expand or improve content quality
# - Monitor pages after changes
#
# ### Cost of a Wrong Recommendation
#
# If a good page is recommended unnecessarily, time and effort are wasted. If an important page is missed, it may continue losing traffic and engagement. Therefore, the recommendations should support human decision-making rather than replace it.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.
import pandas as pd
import json
import os

df = pd.read_csv("data/raw/content_refresh_anonymized.csv")

df = df[(df["impressions_90d"] > 0) & (df["content_age_days"] >= 90)]
df = df.drop_duplicates(subset="content_id")

print("pages after filtering:", len(df))

stale_visible = ((df["days_since_last_update"] >= 180) & (df["impressions_90d"] >= 500)).sum()
print(f"stale + visible pages: {stale_visible}")

declining_with_demand = ((df["trend_direction"] == "down") & (df["impressions_90d"] >= 100)).sum()
print(f"declining pages with real demand: {declining_with_demand}")

# model_results.json is generated by the pipeline — run it if it's missing
if os.path.exists("outputs/model_results.json"):
    with open("outputs/model_results.json") as f:
        results = json.load(f)
    print(results)
else:
    print("model_results.json not found — running the starter pipeline to generate it...")
    # !python scripts/run_all.py
    with open("outputs/model_results.json") as f:
        results = json.load(f)
    print(results)
# Out:
# pages after filtering: 30000
# stale + visible pages: 17
# declining pages with real demand: 13152
# model_results.json not found — running the starter pipeline to generate it...
#
# ...
# ▶ Step 1/5 — Prepare features — clean the data, build the feature vector, define the label
# ...
# Prepared 30,000 rows from 30,000 raw rows
# Wrote /content/Internship/data/processed/refresh_feature_vector.csv
#
# ...
# ▶ Step 2/5 — Baseline — a transparent hand-written rule to beat
# ...
# Wrote baseline queue: /content/Internship/data/processed/baseline_refresh_queue.csv
# Top-50 declining rate (full data, not the evaluated holdout Precision@50): 0.340
#
# ...
# ▶ Step 3/5 — Train — logistic regression, decision tree, random forest (client-holdout split)
# ...
# Trained 3 models on 30,000 rows
# Split strategy: client_holdout
# Best model: random_forest
# Wrote predictions: /content/Internship/data/processed/model_predictions.csv
# Wrote model results: /content/Internship/outputs/model_results.json
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*
#
# I can say a page is a "good candidate to review" based on patterns — not that fixing it will recover its traffic. "Declining" doesn't automatically mean broken — could be seasonality or a sibling page taking its traffic, so I'll have to actually check for that before trusting the label. No claims about causing recovery unless there's an actual before/after test.

# %%
# This cell is for CODE (numbers, a query, a check).
# Write your text answer in the cell ABOVE this one — typing sentences here breaks Run All.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
